# %% [markdown]
# <a href="https://colab.research.google.com/github/danieldrako/Fundamentos-Procesamiento-Lenguaje-Natural-Python-NLTK/blob/main/05Collocations.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Configuración Inicial

# %%
import nltk 
nltk.download('book')
from nltk.book import *
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import plotly.express as px

# %% [markdown]
# #Bi-gramas
# * Parejas de palabras que ocurren consecutivas.

# %%
md_bigrams = list(bigrams(text1))
fdist = FreqDist(md_bigrams)# Conteos 
md_bigrams[:10]
# Out:
# [('[', 'Moby'),
#  ('Moby', 'Dick'),
#  ('Dick', 'by'),
#  ('by', 'Herman'),
#  ('Herman', 'Melville'),
#  ('Melville', '1851'),
#  ('1851', ']'),
#  (']', 'ETYMOLOGY'),
#  ('ETYMOLOGY', '.'),
#  ('.', '(')]

# %% [markdown]
# Aqui podemos obtener los bi-gramas más frecuentes en este texto:

# %%
fdist.most_common(10)
# Out:
# [((',', 'and'), 2607),
#  (('of', 'the'), 1847),
#  (("'", 's'), 1737),
#  (('in', 'the'), 1120),
#  ((',', 'the'), 908),
#  ((';', 'and'), 853),
#  (('to', 'the'), 712),
#  (('.', 'But'), 596),
#  ((',', 'that'), 584),
#  (('.', '"'), 557)]

# %%
fdist.plot(20)

# %% [markdown]
# ## Filtrado de bi-gramas
# * Sin embargo, observamos que los bi-gramas más comunes no representan realmente frases o estructuras léxicas de interes.
# * Tal vez, aplicar algun tipo de filtro nos permita ver estructuras más relevantes.

# %%
threshold = 2
filtered_bigrams = [bigram for bigram in md_bigrams if len(bigram[0])>threshold and len(bigram[1])>threshold]# lista de bigramas filtrado
filtered_dist = FreqDist(filtered_bigrams)
filtered_dist.plot(20)

# %% [markdown]
# # Tri-gramas

# %%
from nltk.util import ngrams
md_trigrams = list(ngrams(text1,3))
fdist = FreqDist(md_trigrams)
md_trigrams[:10]
# Out:
# [('[', 'Moby', 'Dick'),
#  ('Moby', 'Dick', 'by'),
#  ('Dick', 'by', 'Herman'),
#  ('by', 'Herman', 'Melville'),
#  ('Herman', 'Melville', '1851'),
#  ('Melville', '1851', ']'),
#  ('1851', ']', 'ETYMOLOGY'),
#  (']', 'ETYMOLOGY', '.'),
#  ('ETYMOLOGY', '.', '('),
#  ('.', '(', 'Supplied')]

# %%
fdist.most_common(10)
# Out:
# [((',', 'and', 'the'), 187),
#  (('don', "'", 't'), 103),
#  (('of', 'the', 'whale'), 101),
#  ((',', 'in', 'the'), 93),
#  ((',', 'then', ','), 87),
#  (('whale', "'", 's'), 81),
#  (('.', 'It', 'was'), 81),
#  (('ship', "'", 's'), 80),
#  (('the', 'Sperm', 'Whale'), 77),
#  ((',', 'as', 'if'), 76)]

# %%
fdist.plot(10)
